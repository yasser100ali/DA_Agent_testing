# %%
import json

filepath = "message_history/file_details.json"
with open(filepath, "r", encoding="utf-8") as f:
    file_details = json.load(f)

# %%
for key in file_details: print(key)
# Out:
# PMPM_AND_2025_FORECAST.XLSX
# MEMBERSHIP_PREDICTIONS_0221.CSV

# %%
display(file_details["MEMBERSHIP_PREDICTIONS_0221.CSV"])
# Out:
# {'content_hash': 11228323288369449857,
#  'estimated_size_bytes': 172464,
#  'last_updated_timestamp': '2025-06-16T22:43:18.755144+00:00',
#  'sheets': {'primary_sheet': {'row_count': 864,
#    'column_count': 6,
#    'duplicate_row_count': 0,
#    'dataframe_summary': 'This is a summary of the membership predictions',
#    'columns': {'DATE': {'type': 'object',
#      'missing_value_count': 0,
#      'missing_value_percentage': 0.0,
#      'unique_value_count': 12,
#      'is_potential_id': False,
#      'description': '',
#      'categories': ['2025-02-01',
#       '2025-03-01',
#       '2025-04-01',
#       '2025-05-01',
#       '2025-06-01',
#       '2025-07-01',
#       '2025-08-01',
#       '2025-09-01',
#       '2025-10-01',
#       '2025-11-01',
#       '2025-12-01',
#       '2026-01-01']},
#     'FORECAST_LB': {'type': 'float64',
#      'missing_value_count': 0,
#      'missing_value_percentage': 0.0,
#      'unique_value_count': 864,
#      'is_potential_id': True,
# ...

# %%
def write_dataframe_summary(filename, sheet, summary):
    if filename.endswith(".CSV"):
        sheet = "primary_sheet"
    file_details[filename]['sheets'][sheet]['dataframe_summary'] = summary

write_dataframe_summary("MEMBERSHIP_PREDICTIONS_0221.CSV", "primary_sheet", "This is a summary of the membership predictions")

file_details["MEMBERSHIP_PREDICTIONS_0221.CSV"]
# Out:
# {'content_hash': 11228323288369449857,
#  'estimated_size_bytes': 172464,
#  'last_updated_timestamp': '2025-06-16T22:43:18.755144+00:00',
#  'sheets': {'primary_sheet': {'row_count': 864,
#    'column_count': 6,
#    'duplicate_row_count': 0,
#    'dataframe_summary': 'This is a summary of the membership predictions',
#    'columns': {'DATE': {'type': 'object',
#      'missing_value_count': 0,
#      'missing_value_percentage': 0.0,
#      'unique_value_count': 12,
#      'is_potential_id': False,
#      'description': '',
#      'categories': ['2025-02-01',
#       '2025-03-01',
#       '2025-04-01',
#       '2025-05-01',
#       '2025-06-01',
#       '2025-07-01',
#       '2025-08-01',
#       '2025-09-01',
#       '2025-10-01',
#       '2025-11-01',
#       '2025-12-01',
#       '2026-01-01']},
#     'FORECAST_LB': {'type': 'float64',
#      'missing_value_count': 0,
#      'missing_value_percentage': 0.0,
#      'unique_value_count': 864,
#      'is_potential_id': True,
# ...
